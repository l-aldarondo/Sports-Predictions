# %% [markdown]
# ### ETL_wnba_stats
# ### loading data to PostgreSQl database wnba_champs

# %%
# Import our dependencies
import pandas as pd
from path import Path
from sqlalchemy import create_engine
from config import db_password

# %%
# Load the season_stats.csv dataset.
csv_path = Path("./Data/wmba_stats.csv")
stats_df = pd.read_csv(csv_path)
stats_df.head()
# Out:
#    Position   Season   Tm                Team   Age   W   L    W/L%  PW  PL  \
# 0         1  1997-98  HOC      Houston Comets  28.8  18  10  0.6429  22   6
# 1         0  1997-98  PHM     Phoenix Mercury  27.9  16  12  0.5714  20   8
# 2         0  1997-98  NYL    New York Liberty  27.5  17  11  0.6071  17  11
# 3         0  1997-98  LAS  Los Angeles Sparks  25.5  14  14  0.5000  17  11
# 4         0  1997-98  CLR   Cleveland Rockers  28.1  15  13  0.5357  16  12
#
#    ...   3PAr    TS%   eFG%  TOV%  ORB%  FT/FGA  opp_eFG%  opp_TOV%  opp_DRB%  \
# 0  ...  0.292  0.523  0.473  20.4  36.2   0.266     0.444      22.3      64.7
# 1  ...  0.247  0.473  0.411  18.8  33.2   0.274     0.441      24.2      68.5
# 2  ...  0.198  0.482  0.439  21.3  34.6   0.236     0.422      22.7      64.7
# 3  ...  0.136  0.504  0.464  20.4  32.7   0.235     0.423      19.4      67.9
# 4  ...  0.108  0.515  0.464  21.6  32.2   0.276     0.449      20.2      67.1
#
#    opp_FT/FGA
# 0       0.236
# ...

# %%
# remove usless columns
stats_df = stats_df.drop(['Team'], axis=1)
stats_df.head()
# Out:
#    Position   Season   Tm   Age   W   L    W/L%  PW  PL   MOV  ...   3PAr  \
# 0         1  1997-98  HOC  28.8  18  10  0.6429  22   6  6.32  ...  0.292
# 1         0  1997-98  PHM  27.9  16  12  0.5714  20   8  4.00  ...  0.247
# 2         0  1997-98  NYL  27.5  17  11  0.6071  17  11  2.39  ...  0.198
# 3         0  1997-98  LAS  25.5  14  14  0.5000  17  11  2.21  ...  0.136
# 4         0  1997-98  CLR  28.1  15  13  0.5357  16  12  1.79  ...  0.108
#
#      TS%   eFG%  TOV%  ORB%  FT/FGA  opp_eFG%  opp_TOV%  opp_DRB%  opp_FT/FGA
# 0  0.523  0.473  20.4  36.2   0.266     0.444      22.3      64.7       0.236
# 1  0.473  0.411  18.8  33.2   0.274     0.441      24.2      68.5       0.245
# 2  0.482  0.439  21.3  34.6   0.236     0.422      22.7      64.7       0.246
# 3  0.504  0.464  20.4  32.7   0.235     0.423      19.4      67.9       0.263
# 4  0.515  0.464  21.6  32.2   0.276     0.449      20.2      67.1       0.219
#
# [5 rows x 27 columns]

# %%
# renaming columns
stats_df = stats_df.rename(columns={'W/L%': 'Win_pct', 'eFG%': 'eFG_pct','TS%': 'TS_pct', 'TOV%': 'TOV_pct', 'ORB%': 'ORB_pct' ,'FT/FGA': 'FT_FGA',
                                   'opp_eFG%': 'Opp_eFG_pct','opp_TS%': 'Opp_TS_pct', 'opp_TOV%': 'Opp_TOV_pct', 'opp_ORB%': 'Opp_ORB_pct', 'opp_FT/FGA': 'Opp_FT_FGA' })
stats_df.head()
# Out:
#    Position   Season   Tm   Age   W   L  Win_pct  PW  PL   MOV  ...   3PAr  \
# 0         1  1997-98  HOC  28.8  18  10   0.6429  22   6  6.32  ...  0.292
# 1         0  1997-98  PHM  27.9  16  12   0.5714  20   8  4.00  ...  0.247
# 2         0  1997-98  NYL  27.5  17  11   0.6071  17  11  2.39  ...  0.198
# 3         0  1997-98  LAS  25.5  14  14   0.5000  17  11  2.21  ...  0.136
# 4         0  1997-98  CLR  28.1  15  13   0.5357  16  12  1.79  ...  0.108
#
#    TS_pct  eFG_pct  TOV_pct  ORB_pct  FT_FGA  Opp_eFG_pct  Opp_TOV_pct  \
# 0   0.523    0.473     20.4     36.2   0.266        0.444         22.3
# 1   0.473    0.411     18.8     33.2   0.274        0.441         24.2
# 2   0.482    0.439     21.3     34.6   0.236        0.422         22.7
# 3   0.504    0.464     20.4     32.7   0.235        0.423         19.4
# 4   0.515    0.464     21.6     32.2   0.276        0.449         20.2
#
#    opp_DRB%  Opp_FT_FGA
# 0      64.7       0.236
# 1      68.5       0.245
# ...

# %%
#Load the cy_stats.csv dataset (current year).
csv_path = Path("./Data/cy_wnba_stats.csv")
cy_stats_df = pd.read_csv(csv_path)
cy_stats_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2917348/3333340626.py in <module>
#       1 #Load the cy_stats.csv dataset (current year).
#       2 csv_path = Path("./Data/cy_wnba_stats.csv")
# ----> 3 cy_stats_df = pd.read_csv(csv_path)
#       4 cy_stats_df
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# remove usless columns
cy_stats_df = cy_stats_df.drop(['Team'], axis=1)
cy_stats_df.head()
# Out:
#    Position   Season   Tm   Age   W   L    W/L%  PW  PL   MOV  ...   3PAr  \
# 0         0  2021-22  COS  28.3  26   6  0.8125  28   4  9.81  ...  0.298
# 1         1  2021-22  LVA  26.4  24   8  0.7500  26   6  9.06  ...  0.192
# 2         0  2021-22  SES  28.1  21  11  0.6563  22  10  4.44  ...  0.328
# 3         0  2021-22  MLY  27.6  22  10  0.6875  21  11  4.00  ...  0.296
# 4         0  2021-22  PHM  28.4  19  13  0.5938  19  13  2.56  ...  0.332
#
#      TS%   eFG%  TOV%  ORB%  FT/FGA  opp_eFG%  opp_TOV%  opp_DRB%  opp_FT/FGA
# 0  0.543  0.497  15.9  31.2   0.220     0.459      16.1      82.1       0.201
# 1  0.559  0.508  12.6  21.3   0.255     0.464      12.5      80.0       0.165
# 2  0.556  0.512  13.9  20.9   0.206     0.483      14.4      78.6       0.180
# 3  0.553  0.508  15.8  22.3   0.218     0.476      14.6      79.7       0.194
# 4  0.553  0.507  14.7  23.8   0.235     0.466      11.3      75.1       0.167
#
# [5 rows x 27 columns]

# %%
# renaming cy_stats.cvs (current year).
cy_stats_df = cy_stats_df.rename(columns={'W/L%': 'Win_pct', 'eFG%': 'eFG_pct','TS%': 'TS_pct', 'TOV%': 'TOV_pct', 'ORB%': 'ORB_pct' ,'FT/FGA': 'FT_FGA',
                                   'opp_eFG%': 'Opp_eFG_pct','opp_TS%': 'Opp_TS_pct', 'opp_TOV%': 'Opp_TOV_pct', 'opp_ORB%': 'Opp_ORB_pct', 'opp_FT/FGA': 'Opp_FT_FGA' })
cy_stats_df.head()
# Out:
#    Position   Season   Tm   Age   W   L  Win_pct  PW  PL   MOV  ...   3PAr  \
# 0         0  2021-22  COS  28.3  26   6   0.8125  28   4  9.81  ...  0.298
# 1         1  2021-22  LVA  26.4  24   8   0.7500  26   6  9.06  ...  0.192
# 2         0  2021-22  SES  28.1  21  11   0.6563  22  10  4.44  ...  0.328
# 3         0  2021-22  MLY  27.6  22  10   0.6875  21  11  4.00  ...  0.296
# 4         0  2021-22  PHM  28.4  19  13   0.5938  19  13  2.56  ...  0.332
#
#    TS_pct  eFG_pct  TOV_pct  ORB_pct  FT_FGA  Opp_eFG_pct  Opp_TOV_pct  \
# 0   0.543    0.497     15.9     31.2   0.220        0.459         16.1
# 1   0.559    0.508     12.6     21.3   0.255        0.464         12.5
# 2   0.556    0.512     13.9     20.9   0.206        0.483         14.4
# 3   0.553    0.508     15.8     22.3   0.218        0.476         14.6
# 4   0.553    0.507     14.7     23.8   0.235        0.466         11.3
#
#    opp_DRB%  Opp_FT_FGA
# 0      82.1       0.201
# 1      80.0       0.165
# ...

# %%
# Load the cy_stats2.csv dataset.(dummy year)
csv_path = Path("./Data/cy_wnba_stats2.csv")
cy_stats2_df = pd.read_csv(csv_path)
cy_stats2_df
# Out:
#     Position   Season   Tm                Team   Age   W   L    W/L%  PW  PL  \
# 0          1  2016-17  MLY      Minnesota Lynx  30.6  28   6  0.8235  28   6
# 1          0  2016-17  LAS  Los Angeles Sparks  28.7  26   8  0.7647  26   8
# 2          1  2017-18  SES       Seattle Storm  27.6  15  19  0.4412  17  17
# 3          0  2017-18  DAW        Dallas Wings  24.8  16  18  0.4706  13  21
# 4          1  2018-19  WAM  Washington Mystics  27.9  22  12  0.6471  21  13
# 5          0  2018-19  ATD       Atlanta Dream  27.4  23  11  0.6765  20  14
# 6          0  2019-20  INF       Indiana Fever  26.0  13  21  0.3824  13  21
# 7          0  2019-20  NYL    New York Liberty  26.5  10  24  0.2941   7  27
# 8          1  2020-21  CSK         Chicago Sky  27.2  12  10  0.5455  13   9
# 9          0  2020-21  PHM     Phoenix Mercury  28.0  13   9  0.5909  13   9
# 10         1  2021-22  LVA      Las Vegas Aces  26.4  24   8  0.7500  26   6
# ...

# %%
# renaming columns cy_stats2
cy_stats2_df = cy_stats2_df.rename(columns={'W/L%': 'Win_pct', 'eFG%': 'eFG_pct','TS%': 'TS_pct', 'TOV%': 'TOV_pct', 'ORB%': 'ORB_pct' ,'FT/FGA': 'FT_FGA',
                                   'opp_eFG%': 'Opp_eFG_pct','opp_TS%': 'Opp_TS_pct', 'opp_TOV%': 'Opp_TOV_pct', 'opp_ORB%': 'Opp_ORB_pct', 'opp_FT/FGA': 'Opp_FT_FGA' })
cy_stats2_df.head()
# Out:
#    Position   Season   Tm                Team   Age   W   L  Win_pct  PW  PL  \
# 0         1  2016-17  MLY      Minnesota Lynx  30.6  28   6   0.8235  28   6
# 1         0  2016-17  LAS  Los Angeles Sparks  28.7  26   8   0.7647  26   8
# 2         1  2017-18  SES       Seattle Storm  27.6  15  19   0.4412  17  17
# 3         0  2017-18  DAW        Dallas Wings  24.8  16  18   0.4706  13  21
# 4         1  2018-19  WAM  Washington Mystics  27.9  22  12   0.6471  21  13
#
#    ...   3PAr  TS_pct  eFG_pct  TOV_pct  ORB_pct  FT_FGA  Opp_eFG_pct  \
# 0  ...  0.175   0.551    0.500     14.8     30.2   0.254        0.458
# 1  ...  0.245   0.574    0.533     15.9     22.3   0.229        0.471
# 2  ...  0.314   0.574    0.530     16.5     20.8   0.236        0.491
# 3  ...  0.295   0.521    0.453     14.3     29.9   0.308        0.521
# 4  ...  0.344   0.558    0.510     13.0     25.5   0.223        0.496
#
#    Opp_TOV_pct  opp_DRB%  Opp_FT_FGA
# 0         16.7      75.6       0.233
# ...

# %%
# remove usless columns
cy_stats2_df = cy_stats2_df.drop(['Team'], axis=1)
cy_stats2_df.head()
# Out:
#    Position   Season   Tm   Age   W   L  Win_pct  PW  PL   MOV  ...   3PAr  \
# 0         1  2016-17  MLY  30.6  28   6   0.8235  28   6  8.82  ...  0.175
# 1         0  2016-17  LAS  28.7  26   8   0.7647  26   8  7.09  ...  0.245
# 2         1  2017-18  SES  27.6  15  19   0.4412  17  17  0.00  ...  0.314
# 3         0  2017-18  DAW  24.8  16  18   0.4706  13  21 -2.65  ...  0.295
# 4         1  2018-19  WAM  27.9  22  12   0.6471  21  13  3.06  ...  0.344
#
#    TS_pct  eFG_pct  TOV_pct  ORB_pct  FT_FGA  Opp_eFG_pct  Opp_TOV_pct  \
# 0   0.551    0.500     14.8     30.2   0.254        0.458         16.7
# 1   0.574    0.533     15.9     22.3   0.229        0.471         16.1
# 2   0.574    0.530     16.5     20.8   0.236        0.491         14.8
# 3   0.521    0.453     14.3     29.9   0.308        0.521         16.0
# 4   0.558    0.510     13.0     25.5   0.223        0.496         14.9
#
#    opp_DRB%  Opp_FT_FGA
# 0      75.6       0.233
# 1      73.2       0.201
# ...

# %% [markdown]
# ### Initializing database connection

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/wnba_champs"

# %%
engine = create_engine(db_string)

# %% [markdown]
# ### Loading data to wnba_champs database

# %%
stats_df.to_sql(name='stats', con=engine)

# %%
cy_stats_df.to_sql(name='cy_stats', con=engine)

# %%
cy_stats2_df.to_sql(name='cy_stats2', con=engine)
